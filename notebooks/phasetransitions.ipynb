# %%
import sys
sys.path.append("..") 
import numpy as np
import matplotlib.pyplot as plt
from src.sgd.sgd import SGD
from src.plotting.plot_utils import plot_phase_transition
from src.models.regression_model import RegressionModel
from src.data.generate_synthetic_data import transform_to_polynomial
from sklearn.model_selection import train_test_split

# %%
np.random.seed(0)
d_values = [2,3,4,5]
l_values = [2,3]
s = 0.0
noise = 0.0
max_n = 5000  
stepsize_methods = ["fixed", "halving", "diminishing"]

results = {}

# %%
for d in d_values:
    for l in l_values:
        print(f"\n=== Running for d={d}, l={l} ===")

        lower_threshold_n = int((d)**(l+s))
        upper_threshold_n = int((d + 1)**(l + 1 + s))
        ns = np.unique(np.logspace(np.log10(lower_threshold_n / 2), np.log10(upper_threshold_n * 2), num=10, dtype=int))
        ns = [n for n in ns if n >= 5]

        X_raw = np.random.normal(0, 1, size=(max_n, d))
        X_true_poly = transform_to_polynomial(X_raw, degree=l, normalize=True)

        true_A = 0.001 * np.arange(1, X_true_poly.shape[1] + 1)
        true_b = 1.0
        y_full = X_true_poly @ true_A + true_b + np.random.normal(0, noise, size=max_n)

        results[(d, l)] = {method: {"train": [], "test": [], "ns": ns, "weights": []} for method in stepsize_methods}

        for n in ns:
            X_n = X_raw[:n]
            y_n = y_full[:n]
            X_poly_n = transform_to_polynomial(X_n, degree=l, normalize=True)

            X_train, X_test, y_train, y_test = train_test_split(X_poly_n, y_n, test_size=0.3)

            for method in stepsize_methods:
                model = RegressionModel(X_train, y_train)
                sgd = SGD(model=model, num_epochs=n, batch_size=1, noise=noise, stepsize_type=method)
                w, obj, grad, dist = sgd.optimize()

                results[(d, l)][method]["weights"].append(w)
                results[(d, l)][method]["train"].append(obj[-1])
                test_pred = X_test @ w[1:] + w[0]
                test_loss = np.mean((test_pred - y_test) ** 2)
                results[(d, l)][method]["test"].append(test_loss)

                print(f"d={d}, l={l}, n={n}, {method}: Train Loss={obj[-1]:.4f}, Test Loss={test_loss:.4f}")
        plot_phase_transition(
            results=results,
            d=d,
            l=l,
            s=s,
            stepsize_methods=stepsize_methods,
            save_dir="plots")
# Out:
# === Running for d=2, l=2 ===
# d=2, l=2, n=6, fixed: Train Loss=0.4792, Test Loss=1.6899
# d=2, l=2, n=6, halving: Train Loss=0.4786, Test Loss=1.6557
# d=2, l=2, n=6, diminishing: Train Loss=0.4062, Test Loss=1.6049
# d=2, l=2, n=8, fixed: Train Loss=0.4823, Test Loss=0.4162
# d=2, l=2, n=8, halving: Train Loss=0.5018, Test Loss=0.3944
# d=2, l=2, n=8, diminishing: Train Loss=0.5018, Test Loss=0.4017
# d=2, l=2, n=12, fixed: Train Loss=0.4838, Test Loss=0.1509
# d=2, l=2, n=12, halving: Train Loss=0.4830, Test Loss=0.1373
# d=2, l=2, n=12, diminishing: Train Loss=0.4832, Test Loss=0.1463
# d=2, l=2, n=18, fixed: Train Loss=0.0003, Test Loss=0.0672
# d=2, l=2, n=18, halving: Train Loss=0.0003, Test Loss=0.0694
# d=2, l=2, n=18, diminishing: Train Loss=0.0003, Test Loss=0.0701
# d=2, l=2, n=25, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=2, l=2, n=25, halving: Train Loss=0.0000, Test Loss=0.0000
# d=2, l=2, n=25, diminishing: Train Loss=0.0002, Test Loss=0.0010
# d=2, l=2, n=37, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=2, l=2, n=37, halving: Train Loss=0.0000, Test Loss=0.0000
# d=2, l=2, n=37, diminishing: Train Loss=0.0000, Test Loss=0.0000
# d=2, l=2, n=54, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=2, l=2, n=54, halving: Train Loss=0.0000, Test Loss=0.0000
# d=2, l=2, n=54, diminishing: Train Loss=0.0000, Test Loss=0.0000
# Saved plot to plots/phase_transition_d2_l2.png
#
# === Running for d=2, l=3 ===
# d=2, l=3, n=6, fixed: Train Loss=0.4979, Test Loss=0.9819
# d=2, l=3, n=6, halving: Train Loss=0.4876, Test Loss=0.9810
# d=2, l=3, n=6, diminishing: Train Loss=0.4865, Test Loss=0.9830
# d=2, l=3, n=9, fixed: Train Loss=0.4640, Test Loss=0.6419
# d=2, l=3, n=9, halving: Train Loss=0.5328, Test Loss=0.6736
# d=2, l=3, n=9, diminishing: Train Loss=0.4712, Test Loss=0.6438
# d=2, l=3, n=13, fixed: Train Loss=0.0352, Test Loss=0.2219
# d=2, l=3, n=13, halving: Train Loss=0.0378, Test Loss=0.2293
# d=2, l=3, n=13, diminishing: Train Loss=0.0300, Test Loss=0.2026
# d=2, l=3, n=20, fixed: Train Loss=0.0006, Test Loss=0.0043
# d=2, l=3, n=20, halving: Train Loss=0.0006, Test Loss=0.0043
# d=2, l=3, n=20, diminishing: Train Loss=0.0008, Test Loss=0.0051
# d=2, l=3, n=31, fixed: Train Loss=0.0004, Test Loss=0.0081
# d=2, l=3, n=31, halving: Train Loss=0.0003, Test Loss=0.0076
# d=2, l=3, n=31, diminishing: Train Loss=0.0004, Test Loss=0.0099
# d=2, l=3, n=47, fixed: Train Loss=0.0001, Test Loss=0.0010
# d=2, l=3, n=47, halving: Train Loss=0.0001, Test Loss=0.0009
# d=2, l=3, n=47, diminishing: Train Loss=0.0001, Test Loss=0.0013
# d=2, l=3, n=71, fixed: Train Loss=0.0000, Test Loss=0.0001
# d=2, l=3, n=71, halving: Train Loss=0.0000, Test Loss=0.0001
# d=2, l=3, n=71, diminishing: Train Loss=0.0000, Test Loss=0.0004
# d=2, l=3, n=107, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=2, l=3, n=107, halving: Train Loss=0.0000, Test Loss=0.0000
# d=2, l=3, n=107, diminishing: Train Loss=0.0000, Test Loss=0.0002
# d=2, l=3, n=161, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=2, l=3, n=161, halving: Train Loss=0.0000, Test Loss=0.0000
# d=2, l=3, n=161, diminishing: Train Loss=0.0000, Test Loss=0.0000
# Saved plot to plots/phase_transition_d2_l3.png
#
# === Running for d=3, l=2 ===
# d=3, l=2, n=6, fixed: Train Loss=0.4761, Test Loss=1.1861
# d=3, l=2, n=6, halving: Train Loss=0.4376, Test Loss=1.1961
# d=3, l=2, n=6, diminishing: Train Loss=0.4533, Test Loss=1.1774
# d=3, l=2, n=9, fixed: Train Loss=0.5047, Test Loss=0.7920
# d=3, l=2, n=9, halving: Train Loss=0.4998, Test Loss=0.8010
# d=3, l=2, n=9, diminishing: Train Loss=0.5151, Test Loss=0.7859
# d=3, l=2, n=13, fixed: Train Loss=0.0924, Test Loss=0.2530
# d=3, l=2, n=13, halving: Train Loss=0.1045, Test Loss=0.2841
# d=3, l=2, n=13, diminishing: Train Loss=0.0934, Test Loss=0.2629
# d=3, l=2, n=19, fixed: Train Loss=0.0236, Test Loss=0.0771
# d=3, l=2, n=19, halving: Train Loss=0.0240, Test Loss=0.0771
# d=3, l=2, n=19, diminishing: Train Loss=0.0218, Test Loss=0.0703
# d=3, l=2, n=28, fixed: Train Loss=0.0009, Test Loss=0.0622
# d=3, l=2, n=28, halving: Train Loss=0.0009, Test Loss=0.0601
# d=3, l=2, n=28, diminishing: Train Loss=0.0011, Test Loss=0.0727
# d=3, l=2, n=41, fixed: Train Loss=0.0000, Test Loss=0.0001
# d=3, l=2, n=41, halving: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=2, n=41, diminishing: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=2, n=60, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=2, n=60, halving: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=2, n=60, diminishing: Train Loss=0.0000, Test Loss=0.0005
# d=3, l=2, n=88, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=2, n=88, halving: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=2, n=88, diminishing: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=2, n=127, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=2, n=127, halving: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=2, n=127, diminishing: Train Loss=0.0000, Test Loss=0.0000
# Saved plot to plots/phase_transition_d3_l2.png
#
# === Running for d=3, l=3 ===
# d=3, l=3, n=13, fixed: Train Loss=0.2839, Test Loss=1.2683
# d=3, l=3, n=13, halving: Train Loss=0.2939, Test Loss=1.2492
# d=3, l=3, n=13, diminishing: Train Loss=0.2994, Test Loss=1.2422
# d=3, l=3, n=20, fixed: Train Loss=0.0020, Test Loss=5.6625
# d=3, l=3, n=20, halving: Train Loss=0.0029, Test Loss=5.6487
# d=3, l=3, n=20, diminishing: Train Loss=0.0029, Test Loss=5.6377
# d=3, l=3, n=30, fixed: Train Loss=0.0210, Test Loss=0.6807
# d=3, l=3, n=30, halving: Train Loss=0.0209, Test Loss=0.6814
# d=3, l=3, n=30, diminishing: Train Loss=0.0173, Test Loss=0.6773
# d=3, l=3, n=45, fixed: Train Loss=0.0004, Test Loss=0.2918
# d=3, l=3, n=45, halving: Train Loss=0.0005, Test Loss=0.3336
# d=3, l=3, n=45, diminishing: Train Loss=0.0005, Test Loss=0.3401
# d=3, l=3, n=67, fixed: Train Loss=0.0015, Test Loss=0.0448
# d=3, l=3, n=67, halving: Train Loss=0.0013, Test Loss=0.0429
# d=3, l=3, n=67, diminishing: Train Loss=0.0013, Test Loss=0.0426
# d=3, l=3, n=101, fixed: Train Loss=0.0000, Test Loss=0.0001
# d=3, l=3, n=101, halving: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=3, n=101, diminishing: Train Loss=0.0000, Test Loss=0.0005
# d=3, l=3, n=152, fixed: Train Loss=0.0000, Test Loss=0.0001
# d=3, l=3, n=152, halving: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=3, n=152, diminishing: Train Loss=0.0000, Test Loss=0.0001
# d=3, l=3, n=228, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=3, n=228, halving: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=3, n=228, diminishing: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=3, n=341, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=3, n=341, halving: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=3, n=341, diminishing: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=3, n=512, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=3, n=512, halving: Train Loss=0.0000, Test Loss=0.0000
# d=3, l=3, n=512, diminishing: Train Loss=0.0000, Test Loss=0.0000
# Saved plot to plots/phase_transition_d3_l3.png
#
# === Running for d=4, l=2 ===
# d=4, l=2, n=7, fixed: Train Loss=0.4238, Test Loss=2.0599
# d=4, l=2, n=7, halving: Train Loss=0.4512, Test Loss=2.0879
# d=4, l=2, n=7, diminishing: Train Loss=0.4752, Test Loss=2.0680
# d=4, l=2, n=11, fixed: Train Loss=0.4354, Test Loss=1.7851
# d=4, l=2, n=11, halving: Train Loss=0.4481, Test Loss=1.8015
# d=4, l=2, n=11, diminishing: Train Loss=0.4276, Test Loss=1.8005
# d=4, l=2, n=17, fixed: Train Loss=0.1132, Test Loss=0.3130
# d=4, l=2, n=17, halving: Train Loss=0.1065, Test Loss=0.3025
# d=4, l=2, n=17, diminishing: Train Loss=0.1052, Test Loss=0.2967
# d=4, l=2, n=25, fixed: Train Loss=0.0022, Test Loss=0.0828
# d=4, l=2, n=25, halving: Train Loss=0.0021, Test Loss=0.0797
# d=4, l=2, n=25, diminishing: Train Loss=0.0026, Test Loss=0.0881
# d=4, l=2, n=36, fixed: Train Loss=0.0004, Test Loss=0.0030
# d=4, l=2, n=36, halving: Train Loss=0.0003, Test Loss=0.0021
# d=4, l=2, n=36, diminishing: Train Loss=0.0006, Test Loss=0.0040
# d=4, l=2, n=54, fixed: Train Loss=0.0000, Test Loss=0.0003
# d=4, l=2, n=54, halving: Train Loss=0.0000, Test Loss=0.0003
# d=4, l=2, n=54, diminishing: Train Loss=0.0000, Test Loss=0.0009
# d=4, l=2, n=79, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=2, n=79, halving: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=2, n=79, diminishing: Train Loss=0.0000, Test Loss=0.0001
# d=4, l=2, n=116, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=2, n=116, halving: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=2, n=116, diminishing: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=2, n=170, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=2, n=170, halving: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=2, n=170, diminishing: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=2, n=249, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=2, n=249, halving: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=2, n=249, diminishing: Train Loss=0.0000, Test Loss=0.0000
# Saved plot to plots/phase_transition_d4_l2.png
#
# === Running for d=4, l=3 ===
# d=4, l=3, n=32, fixed: Train Loss=0.1838, Test Loss=0.6811
# d=4, l=3, n=32, halving: Train Loss=0.1846, Test Loss=0.6825
# d=4, l=3, n=32, diminishing: Train Loss=0.1786, Test Loss=0.6690
# d=4, l=3, n=48, fixed: Train Loss=0.0317, Test Loss=0.6482
# d=4, l=3, n=48, halving: Train Loss=0.0352, Test Loss=0.6589
# d=4, l=3, n=48, diminishing: Train Loss=0.0302, Test Loss=0.6420
# d=4, l=3, n=72, fixed: Train Loss=0.0017, Test Loss=0.3188
# d=4, l=3, n=72, halving: Train Loss=0.0017, Test Loss=0.3174
# d=4, l=3, n=72, diminishing: Train Loss=0.0018, Test Loss=0.3294
# d=4, l=3, n=108, fixed: Train Loss=0.0003, Test Loss=0.0260
# d=4, l=3, n=108, halving: Train Loss=0.0003, Test Loss=0.0284
# d=4, l=3, n=108, diminishing: Train Loss=0.0003, Test Loss=0.0328
# d=4, l=3, n=163, fixed: Train Loss=0.0000, Test Loss=0.0036
# d=4, l=3, n=163, halving: Train Loss=0.0000, Test Loss=0.0025
# d=4, l=3, n=163, diminishing: Train Loss=0.0001, Test Loss=0.0068
# d=4, l=3, n=245, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=3, n=245, halving: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=3, n=245, diminishing: Train Loss=0.0000, Test Loss=0.0001
# d=4, l=3, n=368, fixed: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=3, n=368, halving: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=3, n=368, diminishing: Train Loss=0.0000, Test Loss=0.0000
# d=4, l=3, n=553, fixed: Train Loss=0.0000, Test Loss=0.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 29
#      27 model = RegressionModel(X_train, y_train)
#      28 sgd = SGD(model=model, num_epochs=n, batch_size=1, noise=noise, stepsize_type=method)
# ---> 29 w, obj, grad, dist = sgd.optimize()
#      31 results[(d, l)][method]["weights"].append(w)
#      32 results[(d, l)][method]["train"].append(obj[-1])
#
# File ~/scie30001/experiments/../src/sgd/sgd.py:49, in SGD.optimize(self)
#      46 X_batch, y_batch = self.X[batch_indices], self.y[batch_indices]
#      48 if self.stepsize_type == 'halving':
# ---> 49     self.strategy.update(self.model.F(w), iteration)
#      50 alpha_k = self.strategy.get(iteration)
#      52 if self.batch_size > 1:
#
# File ~/scie30001/experiments/../src/models/regression_model.py:63, in RegressionModel.F(self, w)
#      53 """
#      54 Full objective (average loss over all samples).
#      55
#    (...)
#      60     Scalar average loss.
#      61 """
#      62 err = self.X @ w - self.y
# ---> 63 return 0.5 * np.mean(err ** 2)
#
# File /opt/anaconda3/envs/sgd-regression/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3380, in _mean_dispatcher(a, axis, dtype, out, keepdims, where)
#    3365     """
#    3366     Round an array to the given number of decimals.
#    3367
#    (...)
#    3375
#    3376     """
#    3377     return _wrapfunc(a, 'round', decimals=decimals, out=out)
# -> 3380 def _mean_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None, *,
#    3381                      where=None):
#    3382     return (a, where, out)
#    3385 @array_function_dispatch(_mean_dispatcher)
#    3386 def mean(a, axis=None, dtype=None, out=None, keepdims=np._NoValue, *,
#    3387          where=np._NoValue):
#
# KeyboardInterrupt:

# %%
# Comparison of weights
d = 3
l_values = [2, 3]
ns2 = [6, 10, 20, 50, 80, 100, 150, 200, 300, 500]

X_raw = np.random.normal(0, 1, size=(max_n, d))
X_true_poly = transform_to_polynomial(X_raw, degree=3, normalize=True)
true_A = 0.001 * np.arange(1, X_true_poly.shape[1] + 1)
true_b = 1.0
y_full = X_true_poly @ true_A + true_b + np.random.normal(0, noise, size=max_n)

results2 = {}
for l in l_values:
    print(f"\n=== Running for d={d}, l={l} ===")
    results2[(d, l)] = {method: {"train": [], "test": [], "ns": ns2, "weights": []} for method in stepsize_methods}
    
    for n in ns2:
        X_n = X_raw[:n]
        y_n = y_full[:n]
        X_poly_n = transform_to_polynomial(X_n, degree=l, normalize=True)

        X_train, X_test, y_train, y_test = train_test_split(X_poly_n, y_n, test_size=0.3)

        for method in stepsize_methods:
            model = RegressionModel(X_train, y_train)
            sgd = SGD(model=model, num_epochs=n, batch_size=1, noise=noise, stepsize_type=method)
            w, obj, grad, dist = sgd.optimize()

            results2[(d, l)][method]["weights"].append(w)
            results2[(d, l)][method]["train"].append(obj[-1])
            test_pred = X_test @ w[1:] + w[0]
            test_loss = np.mean((test_pred - y_test) ** 2)
            results2[(d, l)][method]["test"].append(test_loss)
# Out:
# === Running for d=3, l=2 ===
#
# === Running for d=3, l=3 ===

# %%
def compare_deg3_to_deg2_weights(d, results, method="fixed", delta=1e-3):
    ns_deg3 = results[(d, 3)][method]["ns"]
    ns_deg2 = results[(d, 2)][method]["ns"]
    weights_deg3 = results[(d, 3)][method]["weights"]
    weights_deg2 = results[(d, 2)][method]["weights"]

    print(f"Comparison of degree 3 to degree 2 weights (d = {d}, method = '{method}') \n")
    for n in ns2:
        idx_3 = ns_deg3.index(n)
        idx_2 = ns_deg2.index(n)

        w3 = weights_deg3[idx_3]
        w2 = weights_deg2[idx_2]

        w2_main = w2[1:]
        w3_main = w3[1:len(w2_main)+1] 

        diff = np.abs(w3_main - w2_main)
        significant_diff = diff[diff > delta]
        sum_diff = np.sum(significant_diff)

        print(f"n = {n} | Significant diff terms: {len(significant_diff)} | Sum = {sum_diff:.6f} | Difference by coefficient = {sum_diff/(len(significant_diff)):.6f}")

# %%
compare_deg3_to_deg2_weights(d=3, results=results)
# Out:
# Comparison of degree 3 to degree 2 weights (d = 3, method = 'fixed')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 compare_deg3_to_deg2_weights(d=3, results=results)
#
# Cell In[8], line 9, in compare_deg3_to_deg2_weights(d, results, method, delta)
#       7 print(f"Comparison of degree 3 to degree 2 weights (d = {d}, method = '{method}') \n")
#       8 for n in ns2:
# ----> 9     idx_3 = ns_deg3.index(n)
#      10     idx_2 = ns_deg2.index(n)
#      12     w3 = weights_deg3[idx_3]
#
# ValueError: 6 is not in list
